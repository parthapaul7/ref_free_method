# %%
import os
import numpy as np
import pandas as pd

import pymatgen as pg

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator

# %%
from ref_free_method.ref_free import find_error

df = pd.read_csv('ZnS_example2.csv')
d3_errors = find_error(df)

print("d3 error = " ,d3_errors , 'Eh per f.u.')
# Out:
# d3 error =  0.013764663856831595 Eh per f.u.

# %%
from ref_free_method.visualize import visualize

visualize(df)
